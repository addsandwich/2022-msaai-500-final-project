# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
df = pd.read_csv('TrainingData.csv')
df
# Out:
#        Unnamed: 0        ID  Price  Levy Manufacturer       Model  Prod_year  \
# 0               0  45654403  13328  1399        LEXUS      RX 450       2010
# 1               1  44731507  16621  1018    CHEVROLET     EQUINOX       2011
# 2               2  45774419   8467     0        HONDA         FIT       2006
# 3               3  45769185   3607   862         FORD      ESCAPE       2011
# 4               4  45809263  11726   446        HONDA         FIT       2014
# ...           ...       ...    ...   ...          ...         ...        ...
# 13448       13462  45802417  21103  1104      HYUNDAI    GRANDEUR       2015
# 13449       13463  44631202  13172   530      HYUNDAI     ELANTRA       2013
# 13450       13464  45669073  19757   353       TOYOTA       PRIUS       2015
# 13451       13465  45647811   1019   917          BMW          X5       2013
# 13452       13466  45768173    125  1750       TOYOTA  HIGHLANDER       2008
#
# ...

# %%
ddf = df[['Price','Levy', 'Prod_year', 'Engine_volume', 'Mileage', 'Cylinders', 'Airbags']]
ddf
# Out:
#        Price  Levy  Prod_year  Engine_volume  Mileage  Cylinders  Airbags
# 0      13328  1399       2010            3.5   186005          6       12
# 1      16621  1018       2011            3.0   192000          6        8
# 2       8467     0       2006            1.3   200000          4        2
# 3       3607   862       2011            2.5   168966          4        0
# 4      11726   446       2014            1.3    91901          4        4
# ...      ...   ...        ...            ...      ...        ...      ...
# 13448  21103  1104       2015            3.0   273249          4        4
# 13449  13172   530       2013            1.6    75000          4        8
# 13450  19757   353       2015            1.8   105000          4        8
# 13451   1019   917       2013            3.0   137802          6        0
# 13452    125  1750       2008            3.3   287274          6       12
#
# [13453 rows x 7 columns]

# %%
ddf.corr()
# Out:
#                   Price      Levy  Prod_year  Engine_volume   Mileage  \
# Price          1.000000  0.043694   0.287841       0.130153 -0.017634
# Levy           0.043694  1.000000   0.381583       0.375368 -0.026169
# Prod_year      0.287841  0.381583   1.000000      -0.034592 -0.069824
# Engine_volume  0.130153  0.375368  -0.034592       1.000000 -0.012121
# Mileage       -0.017634 -0.026169  -0.069824      -0.012121  1.000000
# Cylinders      0.104799  0.241199  -0.099391       0.782648 -0.009870
# Airbags       -0.019300  0.126134   0.238808       0.225086 -0.006051
#
#                Cylinders   Airbags
# Price           0.104799 -0.019300
# Levy            0.241199  0.126134
# Prod_year      -0.099391  0.238808
# Engine_volume   0.782648  0.225086
# Mileage        -0.009870 -0.006051
# Cylinders       1.000000  0.170400
# Airbags         0.170400  1.000000

# %%
plt.figure(figsize=(8,8))
sns.heatmap(ddf.corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can see there is Corrlation between Cylinders and Engine Volumes

# %%
normalize = plt.Normalize(vmin = 0, vmax=1)
plt.scatter(ddf['Cylinders'],ddf['Engine_volume'])
plt.show()
#plt.scatter(ddf['Engine_volume'],ddf['Price'])
#plt.show()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Price', 'Levy', 'Manufacturer', 'Model',
#        'Prod_year', 'Category', 'Leather_interior', 'Fuel_type',
#        'Engine_volume', 'Turbo', 'Mileage', 'Cylinders', 'Gear_box_type',
#        'Drive_wheels', 'Doors', 'Wheel', 'Color', 'Airbags'],
#       dtype='object')

# %%
cdf = df[['Manufacturer','Model', 'Category', 'Leather_interior', 'Fuel_type', 'Gear_box_type', 'Drive_wheels', 'Doors', 'Wheel', 'Color']]
cdf
# Out:
#       Manufacturer       Model   Category Leather_interior Fuel_type  \
# 0            LEXUS      RX 450       Jeep              Yes    Hybrid
# 1        CHEVROLET     EQUINOX       Jeep               No    Petrol
# 2            HONDA         FIT  Hatchback               No    Petrol
# 3             FORD      ESCAPE       Jeep              Yes    Hybrid
# 4            HONDA         FIT  Hatchback              Yes    Petrol
# ...            ...         ...        ...              ...       ...
# 13448      HYUNDAI    GRANDEUR      Sedan              Yes       LPG
# 13449      HYUNDAI     ELANTRA      Sedan              Yes    Petrol
# 13450       TOYOTA       PRIUS  Hatchback               No    Hybrid
# 13451          BMW          X5       Jeep              Yes    Diesel
# 13452       TOYOTA  HIGHLANDER      Sedan              Yes    Hybrid
#
#       Gear_box_type Drive_wheels Doors             Wheel   Color
# 0         Automatic   Front-Rear   4-5        Left wheel  Silver
# ...

# %%
cdf1 = cdf.head(50)
ct_counts = cdf1.groupby(['Manufacturer', 'Model']).size()
ct_counts = ct_counts.reset_index(name = 'count')
ct_counts = ct_counts.pivot(index = 'Model', columns = 'Manufacturer', values = 'count')
ct_counts
# Out:
# Manufacturer    BMW  CHEVROLET  FORD  HONDA  HYUNDAI  JEEP  LEXUS  \
# Model
# AQUA            NaN        NaN   NaN    NaN      NaN   NaN    NaN
# CAMRY           NaN        NaN   NaN    NaN      NaN   NaN    NaN
# CAYENNE         NaN        NaN   NaN    NaN      NaN   NaN    NaN
# CHR             NaN        NaN   NaN    NaN      NaN   NaN    NaN
# CHR LIMITED     NaN        NaN   NaN    NaN      NaN   NaN    NaN
# E 220           NaN        NaN   NaN    NaN      NaN   NaN    NaN
# E 350           NaN        NaN   NaN    NaN      NaN   NaN    NaN
# ELANTRA         NaN        NaN   NaN    NaN      5.0   NaN    NaN
# EQUINOX         NaN        1.0   NaN    NaN      NaN   NaN    NaN
# ESCAPE          NaN        NaN   1.0    NaN      NaN   NaN    NaN
# ESCAPE HYBRID   NaN        NaN   1.0    NaN      NaN   NaN    NaN
# FIT             NaN        NaN   NaN    3.0      NaN   NaN    NaN
# GRAND CHEROKEE  NaN        NaN   NaN    NaN      NaN   1.0    NaN
# ...

# %%
sns.heatmap(ct_counts, annot = True)
# Out:
# <AxesSubplot:xlabel='Manufacturer', ylabel='Model'>

# %%
ct_counts = cdf.groupby(['Manufacturer', 'Category']).size()
ct_counts = ct_counts.reset_index(name = 'count')
ct_counts = ct_counts.pivot(index = 'Category', columns = 'Manufacturer', values = 'count')
ct_counts
# Out:
# Manufacturer  ACURA  ALFA ROMEO  ASTON MARTIN  AUDI  BENTLEY    BMW  BUICK  \
# Category
# Cabriolet       NaN         NaN           NaN   NaN      NaN    9.0    NaN
# Coupe           NaN         1.0           1.0   9.0      1.0   61.0    NaN
# Goods wagon     NaN         NaN           NaN   NaN      NaN    NaN    NaN
# Hatchback       NaN         1.0           NaN  23.0      NaN   14.0    NaN
# Jeep            4.0         NaN           NaN  44.0      NaN  300.0    3.0
# Limousine       NaN         NaN           NaN   NaN      NaN    1.0    NaN
# Microbus        NaN         NaN           NaN   NaN      NaN    NaN    NaN
# Minivan         NaN         NaN           NaN   NaN      NaN    NaN    NaN
# Pickup          NaN         NaN           NaN   NaN      NaN    NaN    NaN
# Sedan           7.0         1.0           NaN  88.0      1.0  330.0    6.0
# Universal       NaN         NaN           NaN   3.0      NaN    5.0    NaN
#
# ...

# %%
sns.heatmap(ct_counts, annot = True)
# Out:
# <AxesSubplot:xlabel='Manufacturer', ylabel='Category'>

# %%
ct_counts = cdf.groupby(['Manufacturer', 'Fuel_type']).size()
ct_counts = ct_counts.reset_index(name = 'count')
ct_counts = ct_counts.pivot(index = 'Fuel_type', columns = 'Manufacturer', values = 'count')
ct_counts
# Out:
# Manufacturer    ACURA  ALFA ROMEO  ASTON MARTIN   AUDI  BENTLEY    BMW  BUICK  \
# Fuel_type
# CNG               NaN         NaN           NaN    2.0      NaN   19.0    NaN
# Diesel            NaN         NaN           NaN   13.0      NaN  172.0    NaN
# Hybrid            NaN         NaN           NaN    2.0      NaN    6.0    NaN
# Hydrogen          NaN         NaN           NaN    NaN      NaN    NaN    NaN
# LPG               NaN         NaN           NaN    NaN      NaN   16.0    NaN
# Petrol           11.0         3.0           1.0  150.0      2.0  506.0    9.0
# Plug-in Hybrid    NaN         NaN           NaN    NaN      NaN    1.0    NaN
#
# Manufacturer    CADILLAC  CHEVROLET  CHRYSLER  ...  SSANGYONG  SUBARU  SUZUKI  \
# Fuel_type                                      ...
# CNG                  1.0        NaN       NaN  ...        NaN    12.0     4.0
# Diesel               NaN      188.0       NaN  ...      283.0     NaN     1.0
# ...

# %%
sns.heatmap(ct_counts, annot = True)
# Out:
# <AxesSubplot:xlabel='Manufacturer', ylabel='Fuel_type'>

# %% [markdown]
# Only Honda have Hydrogen. Other fuel type has more than one make has it.

# %%
ct_counts = cdf.groupby(['Manufacturer', 'Gear_box_type']).size()
ct_counts = ct_counts.reset_index(name = 'count')
ct_counts = ct_counts.pivot(index = 'Gear_box_type', columns = 'Manufacturer', values = 'count')
ct_counts
# Out:
# Manufacturer   ACURA  ALFA ROMEO  ASTON MARTIN   AUDI  BENTLEY    BMW  BUICK  \
# Gear_box_type
# Automatic       11.0         NaN           NaN  100.0      1.0  271.0    8.0
# Manual           NaN         2.0           NaN   11.0      NaN   89.0    NaN
# Tiptronic        NaN         1.0           1.0   55.0      1.0  360.0    1.0
# Variator         NaN         NaN           NaN    1.0      NaN    NaN    NaN
#
# Manufacturer   CADILLAC  CHEVROLET  CHRYSLER  ...  SSANGYONG  SUBARU  SUZUKI  \
# Gear_box_type                                 ...
# Automatic          11.0      664.0      14.0  ...      321.0   117.0    36.0
# Manual              1.0       14.0       1.0  ...        NaN    11.0    16.0
# Tiptronic           NaN       69.0       5.0  ...        NaN    53.0     4.0
# Variator            NaN        5.0       NaN  ...        NaN    13.0     3.0
#
# Manufacturer   TESLA  TOYOTA   UAZ   VAZ  VOLKSWAGEN  VOLVO  ZAZ
# Gear_box_type
# ...

# %%
sns.heatmap(ct_counts, annot = True)
# Out:
# <AxesSubplot:xlabel='Manufacturer', ylabel='Gear_box_type'>

# %%
ct_counts = cdf.groupby(['Manufacturer', 'Color']).size()
ct_counts = ct_counts.reset_index(name = 'count')
ct_counts = ct_counts.pivot(index = 'Color', columns = 'Manufacturer', values = 'count')
ct_counts
# Out:
# Manufacturer   ACURA  ALFA ROMEO  ASTON MARTIN  AUDI  BENTLEY    BMW  BUICK  \
# Color
# Beige            NaN         NaN           NaN   1.0      NaN    6.0    NaN
# Black            3.0         2.0           1.0  72.0      2.0  286.0    4.0
# Blue             2.0         NaN           NaN   8.0      NaN   80.0    NaN
# Brown            NaN         NaN           NaN   NaN      NaN   12.0    NaN
# Carnelian red    NaN         NaN           NaN   NaN      NaN    1.0    NaN
# Golden           NaN         NaN           NaN   2.0      NaN    5.0    NaN
# Green            NaN         NaN           NaN   NaN      NaN   12.0    NaN
# Grey             2.0         NaN           NaN  43.0      NaN   88.0    NaN
# Orange           NaN         NaN           NaN   NaN      NaN    4.0    NaN
# Pink             NaN         NaN           NaN   NaN      NaN    1.0    NaN
# Purple           NaN         NaN           NaN   NaN      NaN    1.0    NaN
# ...

# %%
sns.heatmap(ct_counts, annot = True)
# Out:
# <AxesSubplot:xlabel='Manufacturer', ylabel='Color'>

# %%
ct_counts = cdf.groupby(['Category', 'Wheel']).size()
ct_counts = ct_counts.reset_index(name = 'count')
ct_counts = ct_counts.pivot(index = 'Wheel', columns = 'Category', values = 'count')
ct_counts
# Out:
# Category          Cabriolet  Coupe  Goods wagon  Hatchback    Jeep  Limousine  \
# Wheel
# Left wheel             24.0  357.0        156.0     1473.0  3727.0        8.0
# Right-hand drive        NaN   19.0         11.0      525.0   105.0        NaN
#
# Category          Microbus  Minivan  Pickup   Sedan  Universal
# Wheel
# Left wheel           200.0    328.0    33.0  5870.0      217.0
# Right-hand drive       5.0    134.0     1.0   224.0       36.0

# %%
sns.heatmap(ct_counts, annot = True)
# Out:
# <AxesSubplot:xlabel='Category', ylabel='Wheel'>

# %%
ct_counts = cdf.groupby(['Fuel_type', 'Wheel']).size()
ct_counts = ct_counts.reset_index(name = 'count')
ct_counts = ct_counts.pivot(index = 'Wheel', columns = 'Fuel_type', values = 'count')
ct_counts
# Out:
# Fuel_type           CNG  Diesel  Hybrid  Hydrogen    LPG  Petrol  \
# Wheel
# Left wheel        280.0  2785.0  2276.0       1.0  563.0  6434.0
# Right-hand drive   62.0    25.0   212.0       NaN   50.0   710.0
#
# Fuel_type         Plug-in Hybrid
# Wheel
# Left wheel                  54.0
# Right-hand drive             1.0

# %%
sns.heatmap(ct_counts, annot = True)
# Out:
# <AxesSubplot:xlabel='Fuel_type', ylabel='Wheel'>

# %%
sns.pairplot(df,x_vars=['Prod_year','Mileage', 'Airbags'],y_vars=['Price'],hue='Gear_box_type')

# %%
sns.pairplot(df.head(100),x_vars=['Mileage'],y_vars=['Price'],hue='Gear_box_type')

# %%
sns.boxplot(y='Prod_year',x="Gear_box_type", data=df)
# Out:
# <AxesSubplot:xlabel='Gear_box_type', ylabel='Prod_year'>

# %%
sns.boxplot(y='Prod_year',x="Model", data=df)
# Out:
# <AxesSubplot:xlabel='Model', ylabel='Prod_year'>

# %%
sns.boxplot(y='Engine_volume',x="Turbo", data=df)
# Out:
# <AxesSubplot:xlabel='Turbo', ylabel='Engine_volume'>

# %%
sns.pairplot(df.head(200),x_vars=['Engine_volume'],y_vars=['Price'],hue='Turbo')

# %%
df['Turbo']=df['Turbo'].fillna(0)

# %%
sns.pairplot(df.head(100),x_vars=['Engine_volume'],y_vars=['Price'],hue='Turbo')
