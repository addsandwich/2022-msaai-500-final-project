# %%
import data_fix as dfix
import data_utils_g1 as du
import matplotlib.pyplot as plt

# %%
dfix.init()
data = dfix.scrub_txt_file()
# Out:
# Replacing all special characters for clean read
# Asking for cleaned data file save location
# Printing save location:
# C:/Users/chris/Documents/School/Masters/zz_GIT/2022-msaai-500-final-project/data/sanitized/sanitized_1.txt
# C:/Users/chris/Documents/School/Masters/zz_GIT/2022-msaai-500-final-project/data/sanitized/sanitized_1_final.csv

# %%
data
# Out:
#              ID  Price  Levy   Manufacturer    Model Prod_year   Category  \
# 0      45654403  13328  1399          LEXUS   RX 450      2010       Jeep
# 1      44731507  16621  1018      CHEVROLET  EQUINOX      2011       Jeep
# 2      45774419   8467     0          HONDA      FIT      2006  Hatchback
# 3      45769185   3607   862           FORD   ESCAPE      2011       Jeep
# 4      45809263  11726   446          HONDA      FIT      2014  Hatchback
# ...         ...    ...   ...            ...      ...       ...        ...
# 19232  45798355   8467     0  MERCEDES-BENZ  CLK 200      1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   SONATA      2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   TUCSON      2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  CAPTIVA      2007       Jeep
# 19236  45813273    470   753        HYUNDAI   SONATA      2012      Sedan
#
#       Leather_interior Fuel_type Engine_volume  Turbo Mileage Cylinders  \
# 0                  Yes    Hybrid           3.5         186005         6
# 1                   No    Petrol             3         192000         6
# 2                   No    Petrol           1.3         200000         4
# 3                  Yes    Hybrid           2.5         168966         4
# 4                  Yes    Petrol           1.3          91901         4
# ...                ...       ...           ...    ...     ...       ...
# 19232              Yes       CNG           2.0  Turbo  300000         4
# 19233              Yes    Petrol           2.4         161600         4
# 19234              Yes    Diesel             2         116365         4
# 19235              Yes    Diesel             2          51258         4
# 19236              Yes    Hybrid           2.4         186923         4
#
#       Gear_box_type Drive_wheels Doors             Wheel   Color Airbags
# 0         Automatic   Front-Rear   4-5        Left wheel  Silver      12
# 1         Tiptronic   Front-Rear   4-5        Left wheel   Black       8
# 2          Variator        Front   4-5  Right-hand drive   Black       2
# 3         Automatic   Front-Rear   4-5        Left wheel   White       0
# 4         Automatic        Front   4-5        Left wheel  Silver       4
# ...             ...          ...   ...               ...     ...     ...
# 19232        Manual         Rear   2-3        Left wheel  Silver       5
# 19233     Tiptronic        Front   4-5        Left wheel     Red       8
# 19234     Automatic        Front   4-5        Left wheel    Grey       4
# 19235     Automatic        Front   4-5        Left wheel   Black       4
# 19236     Automatic        Front   4-5        Left wheel   White      12
#
# [19237 rows x 19 columns]

# %%
print(data.Gear_box_type.unique())
print(data.Cylinders.unique())
manu = data.Manufacturer.unique()
manu.sort()
print(manu)
mode = data.Model.unique()
mode.sort()
print(len(mode))

cat = data.Category.unique()
print(cat)
# Out:
# ['Automatic' 'Tiptronic' 'Variator' 'Manual']
# ['6' '4' '8' '1' '12' '3' '2' '16' '5' '7' '9' '10' '14']
# ['ACURA' 'ALFA ROMEO' 'ASTON MARTIN' 'AUDI' 'BENTLEY' 'BMW' 'BUICK'
#  'CADILLAC' 'CHEVROLET' 'CHRYSLER' 'CITROEN' 'DAEWOO' 'DAIHATSU' 'DODGE'
#  'FERRARI' 'FIAT' 'FORD' 'GAZ' 'GMC' 'GONOW' 'GREATWALL' 'HAVAL' 'HONDA'
#  'HUMMER' 'HYUNDAI' 'INFINITI' 'ISUZU' 'IVECO DAYLY' 'JAGUAR' 'JEEP' 'KIA'
#  'LAMBORGHINI' 'LANCIA' 'LAND ROVER' 'LEXUS' 'LINCOLN' 'MASERATI' 'MAZDA'
#  'MERCEDES-BENZ' 'MERCURY' 'MINI' 'MITSUBISHI' 'MOSKVICH' 'NISSAN' 'OPEL'
#  'PEUGEOT' 'PONTIAC' 'PORSCHE' 'RENAULT' 'ROLLS-ROYCE' 'ROVER' 'SAAB'
#  'SATURN' 'SCION' 'SEAT' 'SKODA' 'SSANGYONG' 'SUBARU' 'SUZUKI' 'TESLA'
#  'TOYOTA' 'UAZ' 'VAZ' 'VOLKSWAGEN' 'VOLVO' 'ZAZ']
# 1481
# ['Jeep' 'Hatchback' 'Sedan' 'Microbus' 'Goods wagon' 'Universal' 'Coupe'
#  'Minivan' 'Cabriolet' 'Limousine' 'Pickup']

# %% [markdown]
# 1589

# %%
data_dict= {"ID": "Unique identifier/key", "Price": "Price of the car", "Levy": "Tax applied to purchase price", 
            "Manufacturer": "Name of car manufacturer", "Model": "Model of the car", 
            "Prod_year": "Year the car was produced", "Category": "Category by body type of the car", 
            "Leather_interior": "Whether or not the car has a leather interior", "Fuel_type": "Fuel type of the car", 
            "Engine_volume": "Engine size/volume of the car", "Mileage": "Total mileage on the car", 
            "Cylinders": "Number of cylinders", "Gear_box_type": "Type of gear box", "Drive_wheels": 
            "Drive wheels on the car", "Doors": "Number of doors on the car", "Wheel": "Side of the steering wheel", 
            "Color": "Exterior color of the car", "Airbags": "Number of airbags in the car"}

data_dict["ID"]
# Out:
# 'Unique identifier/key'

# %%
file_name = "..\data\data_dictionary.txt"
du.save_py_dict(data_dict)
# Out:
# Asking for dictionary save file path
# 'C:/Users/chris/Documents/School/Masters/zz_GIT/2022-msaai-500-final-project/data/data_dictionary.json'

# %%
data_d = du.load_py_dict()
# Out:
# Asking for dictionary data file path

# %%
data_d
# Out:
# {'ID': 'Unique identifier/key',
#  'Price': 'Price of the car',
#  'Levy': 'Tax applied to purchase price',
#  'Manufacturer': 'Name of car manufacturer',
#  'Model': 'Model of the car',
#  'Prod_year': 'Year the car was produced',
#  'Category': 'Category by body type of the car',
#  'Leather_interior': 'Whether or not the car has a leather interior',
#  'Fuel_type': 'Fuel type of the car',
#  'Engine_volume': 'Engine size/volume of the car',
#  'Mileage': 'Total mileage on the car',
#  'Cylinders': 'Number of cylinders',
#  'Gear_box_type': 'Type of gear box',
#  'Drive_wheels': 'Drive wheels on the car',
#  'Doors': 'Number of doors on the car',
#  'Wheel': 'Side of the steering wheel',
#  'Color': 'Exterior color of the car',
#  'Airbags': 'Number of airbags in the car'}

# %%
gb = data.Gear_box_type.unique()
gb.sort()
du.create_enum_dict(gb)
# Out:
# {'0': 'Automatic', '1': 'Manual', '2': 'Tiptronic', '3': 'Variator'}

# %%
manu = data.Manufacturer.unique()
manu.sort()
print(manu)

print(len(manu))
# Out:
# ['ACURA' 'ALFA ROMEO' 'ASTON MARTIN' 'AUDI' 'BENTLEY' 'BMW' 'BUICK'
#  'CADILLAC' 'CHEVROLET' 'CHRYSLER' 'CITROEN' 'DAEWOO' 'DAIHATSU' 'DODGE'
#  'FERRARI' 'FIAT' 'FORD' 'GAZ' 'GMC' 'GONOW' 'GREATWALL' 'HAVAL' 'HONDA'
#  'HUMMER' 'HYUNDAI' 'INFINITI' 'ISUZU' 'IVECO DAYLY' 'JAGUAR' 'JEEP' 'KIA'
#  'LAMBORGHINI' 'LANCIA' 'LAND ROVER' 'LEXUS' 'LINCOLN' 'MASERATI' 'MAZDA'
#  'MERCEDES-BENZ' 'MERCURY' 'MINI' 'MITSUBISHI' 'MOSKVICH' 'NISSAN' 'OPEL'
#  'PEUGEOT' 'PONTIAC' 'PORSCHE' 'RENAULT' 'ROLLS-ROYCE' 'ROVER' 'SAAB'
#  'SATURN' 'SCION' 'SEAT' 'SKODA' 'SSANGYONG' 'SUBARU' 'SUZUKI' 'TESLA'
#  'TOYOTA' 'UAZ' 'VAZ' 'VOLKSWAGEN' 'VOLVO' 'ZAZ']
# 66

# %%
du.create_enum_dict(manu)
# Out:
# {'0': 'ACURA',
#  '1': 'ALFA ROMEO',
#  '2': 'ASTON MARTIN',
#  '3': 'AUDI',
#  '4': 'BENTLEY',
#  '5': 'BMW',
#  '6': 'BUICK',
#  '7': 'CADILLAC',
#  '8': 'CHEVROLET',
#  '9': 'CHRYSLER',
#  '10': 'CITROEN',
#  '11': 'DAEWOO',
#  '12': 'DAIHATSU',
#  '13': 'DODGE',
#  '14': 'FERRARI',
#  '15': 'FIAT',
#  '16': 'FORD',
#  '17': 'GAZ',
#  '18': 'GMC',
#  '19': 'GONOW',
#  '20': 'GREATWALL',
#  '21': 'HAVAL',
#  '22': 'HONDA',
#  '23': 'HUMMER',
#  '24': 'HYUNDAI',
#  '25': 'INFINITI',
#  '26': 'ISUZU',
#  '27': 'IVECO DAYLY',
#  '28': 'JAGUAR',
#  '29': 'JEEP',
#  '30': 'KIA',
#  '31': 'LAMBORGHINI',
#  '32': 'LANCIA',
#  '33': 'LAND ROVER',
#  '34': 'LEXUS',
#  '35': 'LINCOLN',
#  '36': 'MASERATI',
#  '37': 'MAZDA',
#  '38': 'MERCEDES-BENZ',
#  '39': 'MERCURY',
#  '40': 'MINI',
#  '41': 'MITSUBISHI',
#  '42': 'MOSKVICH',
#  '43': 'NISSAN',
#  '44': 'OPEL',
#  '45': 'PEUGEOT',
#  '46': 'PONTIAC',
#  '47': 'PORSCHE',
#  '48': 'RENAULT',
#  '49': 'ROLLS-ROYCE',
#  '50': 'ROVER',
#  '51': 'SAAB',
#  '52': 'SATURN',
#  '53': 'SCION',
#  '54': 'SEAT',
#  '55': 'SKODA',
#  '56': 'SSANGYONG',
#  '57': 'SUBARU',
#  '58': 'SUZUKI',
#  '59': 'TESLA',
#  '60': 'TOYOTA',
#  '61': 'UAZ',
#  '62': 'VAZ',
#  '63': 'VOLKSWAGEN',
#  '64': 'VOLVO',
#  '65': 'ZAZ'}

# %%
data['Price']
# Out:
# 0        13328
# 1        16621
# 2         8467
# 3         3607
# 4        11726
#          ...
# 19232     8467
# 19233    15681
# 19234    26108
# 19235     5331
# 19236      470
# Name: Price, Length: 19237, dtype: object

# %%
data_types = {}
data_types['Price'] = 'int32'
data_types['Mileage'] = 'int32'
data_types['Prod_year'] = 'int32'
data_types['Airbags'] = 'int32'
data = data.astype(data_types)
data = data.sort_values(by=['ID'])

data2 = data.head(10000)
data2 = data.tail(1000)

print(data.dtypes)


fig, ax = plt.subplots()
ax.scatter(data['Airbags'].head(100),data['Price'].head(100))
ax.set_yscale('log')
ax.set_xscale('log')
#plt.plot(data['Prod_year'].head(10),data['Price'].head(10))
# Out:
# ID                  object
# Price                int32
# Levy                object
# Manufacturer        object
# Model               object
# Prod_year            int32
# Category            object
# Leather_interior    object
# Fuel_type           object
# Engine_volume       object
# Turbo               object
# Mileage              int32
# Cylinders           object
# Gear_box_type       object
# Drive_wheels        object
# Doors               object
# Wheel               object
# Color               object
# Airbags              int32
# dtype: object

# %%
data.head(100)
# Out:
#              ID  Price Levy   Manufacturer               Model  Prod_year  \
# 11219  20746880    157    0  MERCEDES-BENZ               S 500       1939
# 13225  23242980    200    0         TOYOTA  LAND CRUISER PRADO       2017
# 13572  24367759  85702    0  MERCEDES-BENZ        SPRINTER 516       2013
# 3643   24701923    130    0            BMW                  X5       2006
# 5509   24940334  25089    0        LINCOLN           NAVIGATOR       1999
# ...         ...    ...  ...            ...                 ...        ...
# 17395  40164242     30    0         TOYOTA               PRIUS       2008
# 12517  40194711     70    0        HYUNDAI             ELANTRA       2014
# 18936  40219972     40    0         NISSAN                NOTE       2008
# 15050  40220601    110    0            BMW                  X5       2008
# 17454  40379701  30800    0            BMW              530 GT       2009
#
#         Category Leather_interior Fuel_type Engine_volume  Turbo  Mileage  \
# 11219  Limousine              Yes    Petrol           2.4          126000
# 13225       Jeep              Yes    Petrol           2.7           95000
# 13572   Microbus              Yes    Diesel           2.2  Turbo   225000
# 3643        Jeep              Yes    Petrol           4.4           90000
# 5509   Limousine              Yes    Petrol           5.4           99000
# ...          ...              ...       ...           ...    ...      ...
# 17395  Hatchback               No    Hybrid           1.5          100000
# 12517      Sedan              Yes    Petrol           1.8           50000
# 18936  Hatchback               No    Petrol           1.5          100000
# 15050       Jeep              Yes    Petrol             3          121121
# 17454  Hatchback              Yes    Diesel             3          282586
#
#       Cylinders Gear_box_type Drive_wheels Doors             Wheel   Color  \
# 11219         4     Automatic         Rear   4-5        Left wheel   White
# 13225         4     Automatic   Front-Rear     5        Left wheel   Black
# 13572         6        Manual         Rear   2-3        Left wheel   White
# 3643          8     Tiptronic   Front-Rear   4-5        Left wheel   Black
# 5509          8     Automatic   Front-Rear   4-5        Left wheel   White
# ...         ...           ...          ...   ...               ...     ...
# 17395         4      Variator        Front   4-5        Left wheel   White
# 12517         6     Tiptronic        Front   4-5        Left wheel   Brown
# 18936         4     Automatic   Front-Rear   4-5  Right-hand drive  Silver
# 15050         6     Automatic   Front-Rear   4-5        Left wheel   Black
# 17454         6     Automatic         Rear   4-5        Left wheel  Silver
#
#       Airbags
# 11219       0
# 13225      10
# 13572       4
# 3643        8
# 5509        4
# ...       ...
# 17395       8
# 12517       8
# 18936       4
# 15050      10
# 17454      10
#
# [100 rows x 19 columns]

# %%
# Out:
# 11219       157
# 15613       200
# 10265       157
# 6607     119172
# 12849       150
# 3111      51746
# 9026        314
# 19041      3200
# 17071     15681
# 9493       7527
# Name: Price, dtype: int32
